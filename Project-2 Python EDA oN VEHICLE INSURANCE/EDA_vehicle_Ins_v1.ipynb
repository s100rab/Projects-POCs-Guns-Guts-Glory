# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# # Loading the dataset

# %%
columns_cust_details = ['customer_id','Gender','age','driving_licence_present','region_code','previously_insured','vehicle_Age','vehicle_damage']
customer_details = pd.read_csv('Z:\IMPORTANT\local H\GENERAL STUDY\ONLINE LEARNING MODULE\SKILL LYNC\PG- MASTERS - DA-DS\PYTHON-CORE\challenges _ assignment\Project-2 Python EDA oN VEHICLE INSURANCE\customer_details.csv', delimiter=',',header=None, names=columns_cust_details,skiprows=1)
# customer_details.set_index('customer_id',inplace=True)
customer_details
# Out:
#         customer_id  Gender   age  driving_licence_present  region_code  \
# 0               1.0    Male  44.0                      1.0         28.0
# 1               2.0    Male  76.0                      1.0          3.0
# 2               3.0    Male  47.0                      1.0         28.0
# 3               4.0    Male  21.0                      1.0         11.0
# 4               5.0  Female  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0    Male  74.0                      1.0         26.0
# 381105     381106.0    Male  30.0                      1.0         37.0
# 381106     381107.0    Male  21.0                      1.0         30.0
# 381107     381108.0  Female  68.0                      1.0         14.0
# 381108     381109.0    Male  46.0                      1.0         29.0
#
#         previously_insured vehicle_Age vehicle_damage
# ...

# %%
columns_cust_pol_details = ['customer_id','annual_premium(in Rs.)','sales_channel_code','vintage','response']
cust_pol_details = pd.read_csv('Z:\IMPORTANT\local H\GENERAL STUDY\ONLINE LEARNING MODULE\SKILL LYNC\PG- MASTERS - DA-DS\PYTHON-CORE\challenges _ assignment\Project-2 Python EDA oN VEHICLE INSURANCE\customer_policy_details.csv', delimiter=',',header=None, names=columns_cust_pol_details,skiprows=1)
# cust_pol_details.set_index('customer_id',inplace=True)
cust_pol_details
# Out:
#         customer_id  annual_premium(in Rs.)  sales_channel_code  vintage  \
# 0               1.0                 40454.0                26.0    217.0
# 1               2.0                 33536.0                26.0    183.0
# 2               3.0                 38294.0                26.0     27.0
# 3               4.0                 28619.0               152.0    203.0
# 4               5.0                 27496.0               152.0     39.0
# ...             ...                     ...                 ...      ...
# 381104     381105.0                 30170.0                26.0     88.0
# 381105     381106.0                 40016.0               152.0    131.0
# 381106     381107.0                 35118.0               160.0    161.0
# 381107     381108.0                 44617.0               124.0     74.0
# 381108     381109.0                 41777.0                26.0    237.0
#
#         response
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# ...

# %% [markdown]
# # Performing the EDA  on a dataset
# # =================================

# %%
null_summary_customer_details = customer_details.isnull().sum()
null_summary_customer_details
# Out:
# customer_id                386
# Gender                     368
# age                        368
# driving_licence_present    393
# region_code                392
# previously_insured         381
# vehicle_Age                381
# vehicle_damage             407
# dtype: int64

# %%
null_summary_cust_pol_details = cust_pol_details.isnull().sum()
null_summary_cust_pol_details
# Out:
# customer_id               387
# annual_premium(in Rs.)    346
# sales_channel_code        400
# vintage                   388
# response                  361
# dtype: int64

# %%
customer_details.dropna(subset=['customer_id'],inplace=True)
cust_pol_details.dropna(subset=['customer_id'],inplace=True)

# %%
customer_details.shape
# Out:
# (380723, 8)

# %%
cust_pol_details.shape
# Out:
# (380722, 5)

# %%
# customer_details.set_index('customer_id',inplace=True)
# cust_pol_details.set_index('customer_id',inplace=True)

# %%
# # Replace all null values for numeric columns by mean
# numeric_cols_df1 = df1.select_dtypes(include=['number'])
# customer_details['age'] = customer_details['age'].fillna(df1.mean())

# # Replace all null values for Categorical value by mode
# categorical_cols_customer_details = customer_details.select_dtypes(exclude=['number'])
# categorical_cols_customer_details
# customer_details[categorical_cols_customer_details.columns] = customer_details[categorical_cols_customer_details.columns].fillna(customer_details.mode().iloc[0])
# customer_details.isnull().sum()

# %%
customer_details['age'] = customer_details['age'].fillna(customer_details['age'].mean())
customer_details['driving_licence_present'] = customer_details['driving_licence_present'].fillna(customer_details['driving_licence_present'].mode().iloc[0])
customer_details['region_code'] = customer_details['region_code'].fillna(customer_details['region_code'].mode().iloc[0])
customer_details['previously_insured'] = customer_details['previously_insured'].fillna(customer_details['previously_insured'].mode().iloc[0])
customer_details['vehicle_Age'] = customer_details['vehicle_Age'].fillna(customer_details['vehicle_Age'].mode().iloc[0])
customer_details['vehicle_damage'] = customer_details['vehicle_damage'].fillna(customer_details['vehicle_damage'].mode().iloc[0])
customer_details['Gender'] = customer_details['Gender'].fillna(customer_details['Gender'].mode().iloc[0])
customer_details.isnull().sum()
# Out:
# customer_id                0
# Gender                     0
# age                        0
# driving_licence_present    0
# region_code                0
# previously_insured         0
# vehicle_Age                0
# vehicle_damage             0
# dtype: int64

# %%
cust_pol_details['annual_premium(in Rs.)'] = cust_pol_details['annual_premium(in Rs.)'].fillna(cust_pol_details['annual_premium(in Rs.)'].mean())
cust_pol_details['vintage'] = cust_pol_details['vintage'].fillna(cust_pol_details['vintage'].mean())
cust_pol_details['sales_channel_code'] = cust_pol_details['sales_channel_code'].fillna(cust_pol_details['sales_channel_code'].mode().iloc[0])
cust_pol_details['response'] = cust_pol_details['response'].fillna(cust_pol_details['response'].mode().iloc[0])
cust_pol_details.isnull().sum()
# Out:
# customer_id               0
# annual_premium(in Rs.)    0
# sales_channel_code        0
# vintage                   0
# response                  0
# dtype: int64

# %%
# Remove outliers from the 'age' column using the IQR_customer_details method
Q1_customer_details = customer_details['age'].quantile(0.25)
Q3_customer_details= customer_details['age'].quantile(0.75)
IQR_customer_details = Q3_customer_details - Q1_customer_details


customer_details['age'] = customer_details['age'].mask((customer_details['age'] < (Q1_customer_details - 1.5 * IQR_customer_details)) | (customer_details['age'] > (Q3_customer_details + 1.5 * IQR_customer_details)), customer_details['age'].mean())
# customer_details_cleaned = customer_details[~((customer_details['age']
customer_details['age']
# Out:
# 0         44.0
# 1         76.0
# 2         47.0
# 3         21.0
# 4         29.0
#           ...
# 381104    74.0
# 381105    30.0
# 381106    21.0
# 381107    68.0
# 381108    46.0
# Name: age, Length: 380723, dtype: float64

# %%
# # Remove outliers from the 'annual_premium','vintage' from customer policy table column using the IQR_customer_details method
Q1_cust_pol_details = cust_pol_details['annual_premium(in Rs.)'].quantile(0.25)
Q1_cust_pol_details_vin = cust_pol_details['vintage'].quantile(0.25)
Q3_cust_pol_details = cust_pol_details['annual_premium(in Rs.)'].quantile(0.75)
Q3_cust_pol_details_vin = cust_pol_details['vintage'].quantile(0.75)
IQR_cust_pol_details = Q3_cust_pol_details - Q1_cust_pol_details
IQR_cust_pol_details_vin = Q3_cust_pol_details_vin - Q1_cust_pol_details_vin


cust_pol_details['annual_premium(in Rs.)'] = cust_pol_details['annual_premium(in Rs.)'].mask((cust_pol_details['annual_premium(in Rs.)'] < (Q1_cust_pol_details - 1.5 * IQR_cust_pol_details)) | (cust_pol_details['annual_premium(in Rs.)'] > (Q3_cust_pol_details + 1.5 * IQR_cust_pol_details)), cust_pol_details['annual_premium(in Rs.)'].mean())
cust_pol_details['vintage'] = cust_pol_details['vintage'].mask((cust_pol_details['vintage'] < (Q1_cust_pol_details_vin - 1.5 * IQR_cust_pol_details_vin)) | (cust_pol_details['vintage'] > (Q3_cust_pol_details_vin + 1.5 * IQR_cust_pol_details_vin)), cust_pol_details['vintage'].mean())
cust_pol_details['annual_premium(in Rs.)']
cust_pol_details['vintage']
# Out:
# 0         217.0
# 1         183.0
# 2          27.0
# 3         203.0
# 4          39.0
#           ...
# 381104     88.0
# 381105    131.0
# 381106    161.0
# 381107     74.0
# 381108    237.0
# Name: vintage, Length: 380722, dtype: float64

# %%
# Step iii: White spaces
customer_details = customer_details.applymap(lambda x: x.strip() if isinstance(x, str) else x)
cust_pol_details = cust_pol_details.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
# Step iv: Case correction (lower or upper, any one)
# For example, convert all string columns to lowercase
customer_details['vehicle_Age'] = customer_details['vehicle_Age'].str.lower()
customer_details['vehicle_damage'] = customer_details['vehicle_damage'].str.lower()
customer_details['Gender'] = customer_details['Gender'].str.lower()
customer_details
# Out:
#         customer_id  Gender   age  driving_licence_present  region_code  \
# 0               1.0    male  44.0                      1.0         28.0
# 1               2.0    male  76.0                      1.0          3.0
# 2               3.0    male  47.0                      1.0         28.0
# 3               4.0    male  21.0                      1.0         11.0
# 4               5.0  female  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0    male  74.0                      1.0         26.0
# 381105     381106.0    male  30.0                      1.0         37.0
# 381106     381107.0    male  21.0                      1.0         30.0
# 381107     381108.0  female  68.0                      1.0         14.0
# 381108     381109.0    male  46.0                      1.0         29.0
#
#         previously_insured vehicle_Age vehicle_damage
# ...

# %%
object_columns = ['Gender', 'vehicle_Age', 'vehicle_damage']

# Find unique values in each object column
for column in object_columns:
    unique_values = customer_details[column].unique()
    print(f"Unique values in {column}: {unique_values}")
# Out:
# Unique values in Gender: ['male' 'female']
# Unique values in vehicle_Age: ['> 2 years' '1-2 year' '< 1 year']
# Unique values in vehicle_damage: ['yes' 'no']

# %%
# Check unique values in each column before mapping
print("Unique values in Gender:", customer_details['Gender'].unique())
print("Unique values in vehicle_Age:", customer_details['vehicle_Age'].unique())
print("Unique values in vehicle_damage:", customer_details['vehicle_damage'].unique())
# Out:
# Unique values in Gender: ['male' 'female']
# Unique values in vehicle_Age: ['> 2 years' '1-2 year' '< 1 year']
# Unique values in vehicle_damage: ['yes' 'no']

# %%
# Define mappings for each categorical column
gender_mapping = {'male': 0, 'female': 1}
vehicle_age_mapping = {'> 2 years': 3, '1-2 year': 2, '< 1 year': 1}
vehicle_damage_mapping = {'yes': 1, 'no': 0}

# %%
# Map the categorical values to numerical values
customer_details['Gender'] = customer_details['Gender'].map(gender_mapping)
customer_details['vehicle_Age'] = customer_details['vehicle_Age'].map(vehicle_age_mapping)
customer_details['vehicle_damage'] = customer_details['vehicle_damage'].map(vehicle_damage_mapping)

# %%
# Display the DataFrame after mapping
# print(customer_details)
customer_details
# Out:
#         customer_id  Gender   age  driving_licence_present  region_code  \
# 0               1.0       0  44.0                      1.0         28.0
# 1               2.0       0  76.0                      1.0          3.0
# 2               3.0       0  47.0                      1.0         28.0
# 3               4.0       0  21.0                      1.0         11.0
# 4               5.0       1  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0       0  74.0                      1.0         26.0
# 381105     381106.0       0  30.0                      1.0         37.0
# 381106     381107.0       0  21.0                      1.0         30.0
# 381107     381108.0       1  68.0                      1.0         14.0
# 381108     381109.0       0  46.0                      1.0         29.0
#
#         previously_insured  vehicle_Age  vehicle_damage
# ...

# %%
cust_pol_details
# Out:
#         customer_id  annual_premium(in Rs.)  sales_channel_code  vintage  \
# 0               1.0                 40454.0                26.0    217.0
# 1               2.0                 33536.0                26.0    183.0
# 2               3.0                 38294.0                26.0     27.0
# 3               4.0                 28619.0               152.0    203.0
# 4               5.0                 27496.0               152.0     39.0
# ...             ...                     ...                 ...      ...
# 381104     381105.0                 30170.0                26.0     88.0
# 381105     381106.0                 40016.0               152.0    131.0
# 381106     381107.0                 35118.0               160.0    161.0
# 381107     381108.0                 44617.0               124.0     74.0
# 381108     381109.0                 41777.0                26.0    237.0
#
#         response
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# ...

# %%
customer_details = customer_details.drop_duplicates()
customer_details
# Out:
#         customer_id  Gender   age  driving_licence_present  region_code  \
# 0               1.0       0  44.0                      1.0         28.0
# 1               2.0       0  76.0                      1.0          3.0
# 2               3.0       0  47.0                      1.0         28.0
# 3               4.0       0  21.0                      1.0         11.0
# 4               5.0       1  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0       0  74.0                      1.0         26.0
# 381105     381106.0       0  30.0                      1.0         37.0
# 381106     381107.0       0  21.0                      1.0         30.0
# 381107     381108.0       1  68.0                      1.0         14.0
# 381108     381109.0       0  46.0                      1.0         29.0
#
#         previously_insured  vehicle_Age  vehicle_damage
# ...

# %%
# Step vi: Drop Duplicates (duplicated rows)
cust_pol_details = cust_pol_details.drop_duplicates()
cust_pol_details
# Out:
#         customer_id  annual_premium(in Rs.)  sales_channel_code  vintage  \
# 0               1.0                 40454.0                26.0    217.0
# 1               2.0                 33536.0                26.0    183.0
# 2               3.0                 38294.0                26.0     27.0
# 3               4.0                 28619.0               152.0    203.0
# 4               5.0                 27496.0               152.0     39.0
# ...             ...                     ...                 ...      ...
# 381104     381105.0                 30170.0                26.0     88.0
# 381105     381106.0                 40016.0               152.0    131.0
# 381106     381107.0                 35118.0               160.0    161.0
# 381107     381108.0                 44617.0               124.0     74.0
# 381108     381109.0                 41777.0                26.0    237.0
#
#         response
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# ...

# %% [markdown]
# # Merge the dataset to have a master table for our insights

# %%
# Merge the DataFrames based on the 'ID' column
master_table = pd.merge(customer_details, cust_pol_details, on='customer_id', how='inner')

# %%
master_table
# Out:
#         customer_id  Gender   age  driving_licence_present  region_code  \
# 0               1.0       0  44.0                      1.0         28.0
# 1               2.0       0  76.0                      1.0          3.0
# 2               3.0       0  47.0                      1.0         28.0
# 3               4.0       0  21.0                      1.0         11.0
# 4               5.0       1  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 380331     381105.0       0  74.0                      1.0         26.0
# 380332     381106.0       0  30.0                      1.0         37.0
# 380333     381107.0       0  21.0                      1.0         30.0
# 380334     381108.0       1  68.0                      1.0         14.0
# 380335     381109.0       0  46.0                      1.0         29.0
#
#         previously_insured  vehicle_Age  vehicle_damage  \
# ...

# %% [markdown]
# # Conclusion driven from the Master table for business use case

# %% [markdown]
# * i. Gender wise average annual premium

# %%
gender_avg_premium = master_table.groupby('Gender')['annual_premium(in Rs.)'].mean()
gender_avg_premium.index = gender_avg_premium.index.map({0: 'male', 1: 'female'})
print("i. Gender wise average annual premium:")
print(gender_avg_premium)
# Out:
# i. Gender wise average annual premium:
# Gender
# male      29323.099677
# female    29273.474247
# Name: annual_premium(in Rs.), dtype: float64

# %% [markdown]
# * ii. Age wise average annual premium

# %%
age_avg_premium = master_table.groupby('age')['annual_premium(in Rs.)'].mean()
print("i. Age wise average annual premium:")
print(age_avg_premium)
# Out:
# i. Age wise average annual premium:
# age
# 20.0    26342.073517
# 21.0    29751.791916
# 22.0    29946.848634
# 23.0    29838.344763
# 24.0    30125.557096
#             ...
# 81.0    29287.910702
# 82.0    36480.586199
# 83.0    28995.818172
# 84.0    35440.818182
# 85.0    26637.454525
# Name: annual_premium(in Rs.), Length: 67, dtype: float64

# %% [markdown]
# * iii. Check if the data is balanced between genders

# %%
gender_counts = master_table['Gender'].value_counts()

is_balanced = abs(gender_counts.diff().fillna(0)).max() <= 1
# Print the result
print("iii. Is the data balanced between genders?")
print("Data is balanced." if is_balanced else "Data is not balanced.")
# Out:
# iii. Is the data balanced between genders?
# Data is not balanced.

# %% [markdown]
# * iv. Vehicle age wise average annual premium

# %%
vehicle_age_avg_premium = master_table.groupby('vehicle_Age')['annual_premium(in Rs.)'].mean()
vehicle_age_avg_premium.index = vehicle_age_avg_premium.index.map({3:'> 2 years',2:'1-2 year',1:'< 1 year'})
print("iv. Vehicle age wise average annual premium:")
print(vehicle_age_avg_premium)
# Out:
# iv. Vehicle age wise average annual premium:
# vehicle_Age
# < 1 year     29188.150594
# 1-2 year     29102.009839
# > 2 years    32943.540830
# Name: annual_premium(in Rs.), dtype: float64

# %% [markdown]
# * Is there any relation between Person Age and annual premium?

# %%
correlation_coefficient = master_table['age'].corr(master_table['annual_premium(in Rs.)'])


# Determine the strength of the relationship based on the correlation coefficient

if correlation_coefficient < -0.5:
    relationship = "Strong negative relationship"
elif correlation_coefficient > 0.5:
    relationship = "Strong positive relationship"
else:
    relationship = "There is no relationship"

# Print the result
print("Correlation coefficient:", correlation_coefficient)
print("Relationship between Person Age and annual premium:", relationship)
# Out:
# Correlation coefficient: 0.050657589286175454
# Relationship between Person Age and annual premium: There is no relationship

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named df containing all the features

# Calculate the correlation matrix
correlation_matrix = master_table.corr()

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
null_summary_customer_details = customer_details.isnull().sum()
null_summary_customer_details
# Out:
# Gender                     368
# age                          0
# driving_licence_present    392
# region_code                391
# previously_insured         381
# vehicle_Age                381
# vehicle_damage             406
# dtype: int64

# %%
null_summary_cust_pol_details = cust_pol_details.isnull().sum()
null_summary_cust_pol_details
# Out:
# customer_id                 0
# annual_premium(in Rs.)    344
# sales_channel_code        400
# vintage                   388
# response                  361
# dtype: int64

# %%
cust_pol_details.shape
# Out:
# (380722, 5)
